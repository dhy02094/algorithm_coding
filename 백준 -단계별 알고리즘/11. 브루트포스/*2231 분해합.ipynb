# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

for i in range(1, n+1):
    rlt = sum((map(int, str(i))))
    tot_rlt = rlt + i
    if tot_rlt == n :
        print(i)
        break
    if i == n :
        print(0)
# Out:
# 216
# 198
