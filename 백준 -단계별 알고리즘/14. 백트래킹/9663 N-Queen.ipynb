# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = [0] * 8
board = [a] * 8
for i in board[1]:
    print(i)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
a = int(input())
pan = [0] * a
board = [pan] * a

def check():
    if 

def where():
    for i in board
