# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a,b = list(input().split())
re_1 = a[2] + a[1] + a[0]
re_2 = b[2] + b[1] + b[0]
if int(re_1) > int(re_2):
    print(int(re_1))
else :
    print(int(re_2))
# Out:
# 839 237
# 938
