# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t = int(input())
for i in range(t):
    a = list(input().split())
    r = int(a[0])
    s = a[1]
    for j in s:
        print(j*r, end='')
    print('')
# Out:
# 2
# 3 ABC
# AAABBBCCC
# 5 /HTP
# /////HHHHHTTTTTPPPPP
