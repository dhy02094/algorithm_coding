# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
a = input()
croa = ['c=','c-','dz=','d-','lj', 'nj', 's=', 'z=']
cnt = 0

for i in croa:
    a =a.replace(i, '*')
    
len(a)
# Out:
# c=c=
# 2
