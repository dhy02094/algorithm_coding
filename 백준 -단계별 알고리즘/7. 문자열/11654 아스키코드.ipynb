# %% [markdown]
# ![image.png](attachment:image.png)
#
# 출처 : https://www.acmicpc.net/problem/11654

# %%
a = input()
print((ord(a)))

# %% [markdown]
# 풀이 :
#
# 좀 어이없긴한데... 이거 ord를 몰라서 dict 을 써서 {’a’ : 97, ‘b’ : 98 } 이거 하려고 했다......
# 1. 입력 함수 받아오고
# 2. ord를 사용하면 아스키 코드를 반환한다고 한다...
