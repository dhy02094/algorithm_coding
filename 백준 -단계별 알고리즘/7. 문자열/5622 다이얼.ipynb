# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = input()
group = ['ABC','DEF','GHI','JKL','MNO','PQRS','TUV','WXYZ']
ans = 0
for i in a:
    for j in group:
        if i in j:
             ans += group.index(j)

ans = 3*len(a) + ans
print(ans)
# Out:
# UNUCIC
# 36
