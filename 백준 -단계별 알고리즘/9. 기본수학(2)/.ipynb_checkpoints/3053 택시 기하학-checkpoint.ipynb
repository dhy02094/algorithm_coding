# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
import math
n = int(input())
print('%.6f' % (n * math.pi))
print('%.6f' % ((n ** 2) *2))
# Out:
# 21
# 65.973446
# 882.000000
