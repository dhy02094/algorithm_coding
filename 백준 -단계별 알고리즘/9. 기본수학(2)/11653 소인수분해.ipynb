# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

for i in range(2,n+1):
    while 1:
        if n % i == 0:
            n = n // i
            print(i)
        else :
            break
# Out:
# 9991
# 97
# 103
