# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t = int(input())

sol = [0] * 101
sol[1], sol[2], sol[3] = 1, 1, 1

for _ in range(t):
    n = int(input())
    for i in range(4,n+1):
        sol[i] = sol[i-3] + sol[i-2]
        
    print(sol[n])
# Out:
# 2
# 6
# 3
# 12
# 16
