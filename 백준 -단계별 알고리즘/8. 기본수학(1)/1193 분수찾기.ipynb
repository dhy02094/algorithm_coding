# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
x = int(input())

cnt = 0
sum_cnt = 0

while sum_cnt < x:
    cnt += 1
    sum_cnt += cnt
    
if cnt % 2 == 1:
    a = sum_cnt - x + 1
    b = cnt -sum_cnt + x
else :
    a = cnt - sum_cnt + x
    b = sum_cnt -x + 1

    
print(f'{a}/{b}')
# Out:
# 14
# 2/4
