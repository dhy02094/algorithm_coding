# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t = int(input())
for _ in range(t):
    k = int(input())
    n = int(input())
    
    ppl = [i for i in range(1,n+1)]
    print(ppl)
    for x in range(k):
        for y in range(1,n):
            ppl[y] = ppl[y] + ppl[y-1]
            print(ppl)
    print(ppl[-1])
# Out:
# 1
# 3
# 5
# [1, 2, 3, 4, 5]
# [1, 3, 3, 4, 5]
# [1, 3, 6, 4, 5]
# [1, 3, 6, 10, 5]
# [1, 3, 6, 10, 15]
# [1, 4, 6, 10, 15]
# [1, 4, 10, 10, 15]
# [1, 4, 10, 20, 15]
# [1, 4, 10, 20, 35]
# [1, 5, 10, 20, 35]
# [1, 5, 15, 20, 35]
# [1, 5, 15, 35, 35]
# [1, 5, 15, 35, 70]
# 70
