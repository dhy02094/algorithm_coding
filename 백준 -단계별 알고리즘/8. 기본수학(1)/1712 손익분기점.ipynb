# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a,b,c = map(int, input().split())

if (c-b) <= 0:
    print("-1")
else :
    N = int(a / (c-b))+1
    print(N)
# Out:
# 3 2 1
# -1

# %%
210
