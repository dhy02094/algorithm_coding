# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
a = list(map(int, input().split()))

prime = 0

for i in a:
    cnt = 0
    if i==1 :
        continue
    for j in range(2,1001):
        if i % j == 0 :
            cnt += 1
    if cnt == 1:
        prime += 1

print(prime)
# Out:
# 4
# 21 27 29 33
# 1

# %%
5 % 10
# Out:
# 5
