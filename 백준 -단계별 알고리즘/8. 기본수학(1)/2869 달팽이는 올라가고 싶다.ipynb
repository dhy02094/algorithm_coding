# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a,b,v = map(int, input().split())
 
dis = v - a
if dis % (a-b) == 0 :
    t = int(dis/(a-b))
else :
    t = int(dis/(a-b)+1)
    
print(t + 1)
# Out:
# 100 99 1000000000
# 999999901
