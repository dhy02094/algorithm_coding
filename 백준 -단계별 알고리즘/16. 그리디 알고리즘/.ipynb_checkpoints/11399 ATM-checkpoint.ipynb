# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
time = list(map(int, input().split()))
a = 0
b = []
time.sort()
for i in time:
    a += i
    b.append(a)
print(sum(b))
# Out:
# 5
# 3 1 4 3 2
# 32
