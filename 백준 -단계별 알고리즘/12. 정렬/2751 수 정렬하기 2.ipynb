# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys 

n = int(input())
ans = [0] * 10001
for _ in range(n):
    a = int(sys.stdin.readline())
    
    ans[a] += 1 

for i in range(10001):
    if a[i] != 0:
        for j in range(a[i]):
            print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/f4/fb3b_sqx3rvc3gfr73v6ck_00000gn/T/ipykernel_70008/4123039926.py in <module>
#       1 import sys
#       2
# ----> 3 n = int(input())
#       4 ans = [0] * 10001
#       5 for _ in range(n):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf26/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf26/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
# ...
