# %% [markdown]
# https://www.acmicpc.net/problem/2750
# ![image.png](attachment:image.png)

# %%
n = int(input())
ans = []
for _ in range(n):
    a = int(input())
    ans.append(a)
ans.sort()
for i in ans:
    print(i)
# Out:
# 5
# 5
# 2
# 3
# 4
# 1
# 1
# 2
# 3
# 4
# 5
