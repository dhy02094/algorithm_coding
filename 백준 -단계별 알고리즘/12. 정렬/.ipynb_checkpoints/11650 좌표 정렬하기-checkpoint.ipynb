# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())

a = []
for _ in range(n):
    x, y = map(int, input().split())
    a.append((x,y))
    
a.sort()
for i in a:
    print(i[0], i[1])
# Out:
# 5
# 0 4
# 1 2
# 1 1
# 2 2
# 3 3
# 3 3
# 2 2
# 1 2
# 1 1
# 0 4

# %% [markdown]
# #
