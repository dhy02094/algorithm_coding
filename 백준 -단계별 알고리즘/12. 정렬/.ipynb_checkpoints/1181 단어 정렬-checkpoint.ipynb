# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys
n = int(sys.stdin.readline())

word = []
for _ in range(n):
    word.append(sys.stdin.readline().strip())
uni_word = list(set(word))
uni_word.sort()
uni_word.sort(key=len)

for i in uni_word:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/f4/fb3b_sqx3rvc3gfr73v6ck_00000gn/T/ipykernel_74581/4117428926.py in <module>
#       1 import sys
# ----> 2 n = int(sys.stdin.readline())
#       3
#       4 word = []
#       5 for _ in range(n):
#
# ValueError: invalid literal for int() with base 10: ''
